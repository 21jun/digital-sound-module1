# %%
import scipy.io.wavfile as wf
import numpy as np             
import pandas as pd
from matplotlib import pyplot as plt
from pathlib import Path 
from math import cos,pi 
import main
from pathlib import Path

# %%
path = Path("music/").glob("**/*.wav")
files = [x for x in path if x.is_file()]

# %%
for file in files:
    main.convert(file_path=file, function=main.cosine_function)
    main.convert(file_path=file, function=main.euclidean)
# Out:
# cosine_function converting:                  sample!!!!.wav ... done
# euclidean       converting:                  sample!!!!.wav ... done

# %%
rate1, data1 = wf.read('music/sample!!!!.wav')
left1 = data1[:, 0]
right1 = data1[:, 1]

# %%
rate2, data2 = wf.read('out/sample!!!!_cosine_function.wav')
left2 = data2[:, 0]
right2 = data2[:, 1]

# %%
rate3, data3 = wf.read('out/sample!!!!_euclidean.wav')
left3 = data3[:, 0]
right3 = data3[:, 1]

# %%
fig, axs = plt.subplots(2, figsize=(20,10))
fig.suptitle('')
axs[0].plot(left1, alpha=0.7)
axs[0].plot(left2, alpha=0.7)
# axs[0].plot(left3, alpha=1)


axs[1].plot(right1,  alpha=0.7)
axs[1].plot(right2, alpha=0.7)
# axs[1].plot(right3, alpha=1)
plt.show()

# %%
right.max9)
# Out:
#   File "<ipython-input-10-ab83c348bd7d>", line 1
#     right.max9)
#               ^
# SyntaxError: invalid syntax
